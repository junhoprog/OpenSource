# %%
# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc
font_path="./malgun.ttf"
font_name=font_manager.FontProperties(fname=font_path).get_name()
rc('font',family=font_name)

# 파일경로를 찾고, 변수 file_path에 저장
file_path = './projectdata.csv'

# read_csv() 함수로 데이터프레임 변환. 변수 df1에 저장
df = pd.read_csv(file_path,encoding='cp949')

df.index=['전국','서울','부산','대구','인천','광주','대전','울산','세종','경기도','강원도','충북','충남','전북','전남','경북','경남','제주']
print(df)

print('\n')
#충청북도의 출산율 데이터만 추출하여 정리
col_age=['합계출산율','15-19','20-24','25-29','30-34','35-39','40-44','45-49']
df_2=df.loc[['전국','충북'],col_age]

fig=plt.figure(figsize=(10,5))
ax=fig.add_subplot(1,1,1)
ax.plot(col_age,df_2.loc['충북',:],marker='o',markersize=10,markerfacecolor='green')
ax.plot(col_age,df_2.loc['전국',:],marker='o',markersize=10,markerfacecolor='red')
ax.set_title('충북-전국 출산율 비교')
ax.set_xlabel('연령')
ax.set_ylabel('출산율')

test=df.loc[:, ['25-29','30-34']]
grouped=test.groupby(['30-34'])
print(grouped)
#'지역','전국','서울','부산','대구','인천','광주','대전','울산','세종','경기도','강원도','충북','충남','전북','전남','경북','경남','제주'

'''
1)groupby를 사용한 데이터 그룹화 후 간단한 통계 분석(method3개이상사용)
2)matplotlib를 활용한 그래프 그리기 (그래프 종류는 자유, 그래프 2가지 이상)
3)머신러닝 기법 1개 이상을 사용한 모델학습 및 모델 평가 수치 게산
'''
# Out:
#      합계출산율  15-19  20-24  25-29  30-34  35-39  40-44  45-49
# 전국   0.808    0.4    5.0   27.5   76.1   43.5    7.6    0.2
# 서울   0.626    0.2    1.8   12.1   57.6   43.9    8.3    0.2
# 부산   0.728    0.2    3.7   21.4   69.8   41.6    7.2    0.1
# 대구   0.785    0.5    4.0   25.6   76.8   41.1    6.3    0.1
# 인천   0.778    0.7    5.3   27.5   71.0   42.1    7.7    0.2
# 광주   0.896    0.6    5.0   32.0   86.1   45.2    7.3    0.3
# 대전   0.810    0.5    5.0   28.9   76.6   41.9    6.8    0.2
# 울산   0.940    0.1    5.9   38.5   95.1   39.7    6.6    0.1
# 세종   1.277    0.2    6.3   54.6  128.1   58.4    8.6    0.1
# 경기도  0.853    0.4    4.9   29.0   81.2   45.6    7.9    0.2
# 강원도  0.979    0.5    8.5   47.0   87.2   43.1    7.3    0.2
# 충북   0.949    0.7    8.4   43.0   88.4   40.8    6.3    0.2
# 충남   0.963    0.6    9.8   46.6   86.2   40.8    7.0    0.2
# 전북   0.850    0.6    6.9   36.5   75.9   40.3    7.3    0.2
# 전남   1.017    0.8    9.2   46.0   92.8   44.5    7.8    0.2
# 경북   0.966    0.7    7.5   43.5   89.2   42.8    7.6    0.1
# 경남   0.903    0.4    6.3   38.7   87.0   39.5    6.5    0.2
# 제주   0.951    0.2    9.0   38.3   81.7   47.6   10.7    0.4
#
#
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000019A63B12408>
# '\n1)groupby를 사용한 데이터 그룹화 후 간단한 통계 분석(method3개이상사용)\n2)matplotlib를 활용한 그래프 그리기 (그래프 종류는 자유, 그래프 2가지 이상)\n3)머신러닝 기법 1개 이상을 사용한 모델학습 및 모델 평가 수치 게산\n'
